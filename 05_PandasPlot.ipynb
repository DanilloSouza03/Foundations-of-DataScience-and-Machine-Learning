# %% [markdown]
# ## Pandas Plot
#
# **Pandas Plot e Plotly**
#
# *Autor: Danillo de Souza*

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("dataframes/flights.csv", sep=",")
df.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'passengers'}>]], dtype=object)

# %%
df['passengers'].plot.area()
# Out:
# <AxesSubplot:>

# %%
df['passengers'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='year',y='passengers',c='year')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
df.plot.line(x='year',y='passengers')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df['year'].plot.box()
# Out:
# <AxesSubplot:>
